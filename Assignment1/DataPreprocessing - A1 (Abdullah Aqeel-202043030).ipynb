# %% [markdown]
# # COMP3400/6981 Assignment 1

# %% [markdown]
# **Name:** *Abdullah Aqeel*
#
# **MUN id:** *202043030*
#
# The dataset you will be using in this assignment was downloaded from Kaggle (https://www.kaggle.com/datasets/cashncarry/fifa-23-complete-player-dataset) and contains data about players in FIFA 23 (A Soccer/Football video game developed by Electronic Arts(EA)).
#
# For a better understanding of the dataset, please read the information available at the URL and explore the dataset in this notebook. From here on out we will refer to the sport as soccer, to avoid any confusion. There's no in-depth description of the features, but most of them are intuitive. Here is a description created by the instructional staff for your reference for the columns we will be using through this assignment.
#
# **ID:** Player's unique identifier.
#
# **Name:** Player's abbreviated name.
#
# **FullName:** Player's full name.
#
# **Age:** Player's age.
#
# **Height:** Player's height.
#
# **Weight:** Player's weight.
#
# **Nationality:** Player's nationality.
#
# **Overall:** Player's overall statistics regarding their abilities.
#
# **Potential:** Player's potential.
#
# **Growth:** Player's growth.
#
# **BestPosition:** Position in the field that a player generally plays.
#
# **Club:** The Club that the player plays for.
#
# **ValueEUR:** Value in Euro of the player.
#
# **WageEUR:** Wage of the player in Euro.
#
# Note this dataset was last updated in January, so information may be outdated or incorrect.
# Use the following two cells to make sure you are loading the dataset correctly.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('players_fifa23.csv')

df
# Out:
#            ID            Name            FullName  Age  Height  Weight  \
# 0      165153      K. Benzema       Karim Benzema   34     185      81
# 1      158023        L. Messi        Lionel Messi   35     169      67
# 2      231747       K. Mbappé       Kylian Mbappé   23     182      73
# 3      192985    K. De Bruyne     Kevin De Bruyne   31     181      70
# 4      188545  R. Lewandowski  Robert Lewandowski   33     185      81
# ...       ...             ...                 ...  ...     ...     ...
# 18355  261899    Chen Keqiang        Keqiang Chen   22     183      70
# 18356  271152       M. Furaih     Mohammed Furaih   22     162      60
# 18357  269578        Ning Hao            Hao Ning   37     175      70
# 18358  269577     Feng Zeyuan         Zeyuan Feng   20     181      70
# 18359  259649        E. Singh        Engson Singh   19     169      62
#
#                                                PhotoUrl   Nationality  \
# 0      https://cdn.sofifa.net/players/165/153/23_60.png        France
# 1      https://cdn.sofifa.net/players/158/023/23_60.png     Argentina
# 2      https://cdn.sofifa.net/players/231/747/23_60.png        France
# 3      https://cdn.sofifa.net/players/192/985/23_60.png       Belgium
# 4      https://cdn.sofifa.net/players/188/545/23_60.png        Poland
# ...                                                 ...           ...
# 18355  https://cdn.sofifa.net/players/261/899/23_60.png      China PR
# 18356  https://cdn.sofifa.net/players/271/152/23_60.png  Saudi Arabia
# 18357  https://cdn.sofifa.net/players/269/578/23_60.png      China PR
# 18358  https://cdn.sofifa.net/players/269/577/23_60.png      China PR
# 18359  https://cdn.sofifa.net/players/259/649/23_60.png         India
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 0           91         91  ...        89        84        89        67
# 1           91         91  ...        91        88        91        67
# 2           91         95  ...        92        84        92        70
# 3           91         91  ...        91        91        91        82
# 4           91         91  ...        86        83        86        67
# ...        ...        ...  ...       ...       ...       ...       ...
# 18355       48         54  ...        49        50        49        51
# 18356       48         57  ...        50        45        50        39
# 18357       48         48  ...        48        48        48        47
# 18358       48         58  ...        47        42        47        36
# 18359       48         63  ...        49        49        49        44
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating  GKRating
# 0            67        67        63        58        63        21
# 1            66        67        62        53        62        22
# 2            66        70        66        57        66        21
# 3            82        82        78        72        78        24
# 4            69        67        64        63        64        22
# ...         ...       ...       ...       ...       ...       ...
# 18355        52        51        52        52        52        19
# 18356        36        39        37        29        37        17
# 18357        47        47        46        43        46        18
# 18358        33        36        35        31        35        15
# 18359        43        44        43        39        43        14
#
# [18360 rows x 90 columns]

# %%
df.describe()
# Out:
#                   ID           Age        Height        Weight       Overall  \
# count   18360.000000  18360.000000  18360.000000  18360.000000  18360.000000
# mean   236693.153704     25.303540    181.526089     75.139869     65.832680
# std     26493.482449      4.693175      6.857984      6.998178      6.802402
# min      1179.000000     16.000000    155.000000     49.000000     48.000000
# 25%    221466.250000     22.000000    177.000000     70.000000     62.000000
# 50%    240997.000000     25.000000    182.000000     75.000000     66.000000
# 75%    258527.250000     29.000000    186.000000     80.000000     70.000000
# max    271341.000000     44.000000    206.000000    105.000000     91.000000
#
#           Potential        Growth    TotalStats     BaseStats      ValueEUR  \
# count  18360.000000  18360.000000  18360.000000  18360.000000  1.836000e+04
# mean      70.959532      5.126852   1602.493682    357.932026  2.881407e+06
# std        6.171324      5.312458    272.296129     39.700131  7.679217e+06
# min       48.000000      0.000000    759.000000    224.000000  0.000000e+00
# 25%       67.000000      0.000000   1470.000000    331.000000  4.750000e+05
# 50%       71.000000      4.000000   1640.000000    358.000000  9.750000e+05
# 75%       75.000000      9.000000   1785.000000    385.000000  2.000000e+06
# max       95.000000     26.000000   2312.000000    502.000000  1.905000e+08
#
#        ...      LMRating      CMRating      RMRating     LWBRating  \
# count  ...  18360.000000  18360.000000  18360.000000  18360.000000
# mean   ...     58.476906     57.388508     58.476906     56.292266
# std    ...     13.940940     13.138632     13.940940     13.854138
# min    ...     18.000000     18.000000     18.000000     17.000000
# 25%    ...     54.000000     53.000000     54.000000     51.000000
# 50%    ...     62.000000     60.000000     62.000000     59.000000
# 75%    ...     67.000000     66.000000     67.000000     66.000000
# max    ...     92.000000     91.000000     92.000000     88.000000
#
#           CDMRating     RWBRating      LBRating      CBRating      RBRating  \
# count  18360.000000  18360.000000  18360.000000  18360.000000  18360.000000
# mean      55.931917     56.292266     55.657789     54.534423     55.657789
# std       13.841226     13.854138     14.108821     14.708686     14.108821
# min       19.000000     17.000000     17.000000     18.000000     17.000000
# 25%       48.000000     51.000000     49.000000     45.000000     49.000000
# 50%       59.000000     59.000000     59.000000     58.000000     59.000000
# 75%       66.000000     66.000000     65.000000     66.000000     65.000000
# max       89.000000     88.000000     87.000000     90.000000     87.000000
#
#            GKRating
# count  18360.000000
# mean      23.193900
# std       15.059682
# min       10.000000
# 25%       17.000000
# 50%       18.000000
# 75%       20.000000
# max       90.000000
#
# [8 rows x 78 columns]

# %% [markdown]
# ## Task 1 - Removing and Creating columns (15 marks)
#
# For this task you need to show that you can handle simple pre-processing steps such as removing and creating new attributes in your dataframe. The tasks you must perform in this unit are listed below.
#
# 1. Remove all columns to the right of WageEUR as we won't use them in this assignment.
# 2. Remove *TotalStats, BaseStats, Positions*, and *PhotoUrl*
# 3. Add An additional column labeled as GMValue (General Manager Value), that computes the following equation: $ 'Overall' * 0.9 + 'Growth'$, where overall and growth are columns present in your dataframe.
# 4. Add two other columns, one for first name (label it as FirstName), and one for last name (label it as LastName).
# 5. Finally, sort your dataframe using GMValue in descending order
#
# **Tip:** Print your dataframe in the end of this task and make sure it has 17 columns (this includes the three new ones created in this task).

# %%
# Type your answers here #
# You may use multiple cells, but make sure you show the # 
# last configuration of your dataframe for proper assessment #
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('players_fifa23.csv')
#df_task1= df.drop(df.loc[: ,'WageEUR'::].columns,axis=1) 

#Number 1
df_task1 = df.drop(df.iloc[:, 17+1:], axis=1)

#Number2
df_task1 = df_task1.drop(["TotalStats", "BaseStats", "Positions", "PhotoUrl"],axis=1) 

#Number3
df_task1['GMValue'] = df_task1.apply(lambda row: row.Overall * 0.9 + row.Growth, axis=1)  

#Number4
df_task1[['FirstName','LastName']] = df_task1['Name'].loc[df_task1['Name'].str.split().str.len() == 2].str.split(expand=True)  
df_task1['LastName'].fillna(df_task1['Name'],inplace=True)

#Number5
df_task1 = df_task1.sort_values('GMValue', ascending=False) 


df_task1
# Out:
#            ID          Name                          FullName  Age  Height  \
# 2      231747     K. Mbappé                     Kylian Mbappé   23     182
# 29     239085    E. Haaland                    Erling Haaland   21     195
# 67     251854         Pedri              Pedro González López   19     174
# 68     237692      P. Foden                        Phil Foden   22     171
# 57     238794  Vinícius Jr.  Vinícius José de Oliveira Júnior   21     176
# ...       ...           ...                               ...  ...     ...
# 18138  257936      Song Yue                          Yue Song   30     185
# 18309  269482   Wang Hanlin                       Hanlin Wang   32     180
# 18304  269478   Hu Mingtian                       Mingtian Hu   27     181
# 18332  261904  S. Abdusalam                   Sabit Abdusalam   28     178
# 18357  269578      Ning Hao                          Hao Ning   37     175
#
#        Weight Nationality  Overall  Potential  Growth BestPosition  \
# 2          73      France       91         95       4           ST
# 29         94      Norway       88         94       6           ST
# 67         61       Spain       85         93       8           CM
# 68         69     England       85         92       7          CAM
# 57         73      Brazil       86         92       6           LW
# ...       ...         ...      ...        ...     ...          ...
# 18138      84    China PR       51         51       0           CB
# 18309      69    China PR       50         50       0          CDM
# 18304      72    China PR       50         50       0           LM
# 18332      69    China PR       49         49       0           ST
# 18357      70    China PR       48         48       0          CAM
#
#                                     Club   ValueEUR  WageEUR  GMValue  \
# 2                    Paris Saint-Germain  190500000   230000     85.9
# 29                       Manchester City  148000000   220000     85.2
# 67                          FC Barcelona  116000000   115000     84.5
# 68                       Manchester City  109500000   180000     83.5
# 57                        Real Madrid CF  109000000   200000     83.4
# ...                                  ...        ...      ...      ...
# 18138            Tianjin Jinmen Tiger FC      50000     1000     45.9
# 18309             Chengdu Rongcheng F.C.      30000     1000     45.0
# 18304             Chengdu Rongcheng F.C.      50000     1000     45.0
# 18332      Shijiazhuang Ever Bright F.C.      45000     1000     44.1
# 18357  Dalian Professional Football Club      15000     1000     43.2
#
#       FirstName   LastName
# 2            K.     Mbappé
# 29           E.    Haaland
# 67          NaN      Pedri
# 68           P.      Foden
# 57     Vinícius        Jr.
# ...         ...        ...
# 18138      Song        Yue
# 18309      Wang     Hanlin
# 18304        Hu   Mingtian
# 18332        S.  Abdusalam
# 18357      Ning        Hao
#
# [18360 rows x 17 columns]

# %% [markdown]
# ## Task 2 - Aggregating and Summarizing information (30 marks)
#
# In the this task, we are interested in discovering several things about the players described in the dataset. Please write your queries in the cells below and answer them in this section.
#
# 1. Who are the top 5 best soccer players (i.e., use attribute *Overall* to determine the best player)?
#
#     **Answer:** *K. Mbappé, K. Benzema, K. De Bruyne, R. Lewandowski, L. Messi*
#
#
# 2. Who are the top 5 best soccer players under the age of 25?
#
#     **Answer:** *K. Mbappé, E. Haaland, G. Donnarumma, T. Alexander-Arnold, Vinícius Jr.*
#
#
# 3. Who is the tallest player?
#
#     **Answer:** *K. Hudlin and T. Holý*
#
#
# 4. Who is the best player from Canada and what team does he play for?
#
#     **Answer:** *A. Davies and he playes for FC Bayern Munich*

# %%
# Type your answers here #
# You may use multiple cells, but make sure you answer # 
# the questions using the cell above #

#Question1 Task2
best5Overall = df_task1.sort_values('Overall', ascending=False)
best5Overall_Top5 = best5Overall.head(5)


best5Overall_Top5
# Out:
#        ID            Name            FullName  Age  Height  Weight  \
# 2  231747       K. Mbappé       Kylian Mbappé   23     182      73
# 0  165153      K. Benzema       Karim Benzema   34     185      81
# 3  192985    K. De Bruyne     Kevin De Bruyne   31     181      70
# 4  188545  R. Lewandowski  Robert Lewandowski   33     185      81
# 1  158023        L. Messi        Lionel Messi   35     169      67
#
#   Nationality  Overall  Potential  Growth BestPosition                 Club  \
# 2      France       91         95       4           ST  Paris Saint-Germain
# 0      France       91         91       0           CF       Real Madrid CF
# 3     Belgium       91         91       0           CM      Manchester City
# 4      Poland       91         91       0           ST         FC Barcelona
# 1   Argentina       91         91       0          CAM  Paris Saint-Germain
#
#     ValueEUR  WageEUR  GMValue FirstName      LastName
# 2  190500000   230000     85.9        K.        Mbappé
# 0   64000000   450000     81.9        K.       Benzema
# 3  107500000   350000     81.9       NaN  K. De Bruyne
# 4   84000000   420000     81.9        R.   Lewandowski
# 1   54000000   195000     81.9        L.         Messi

# %%
#Question2 Task2
best50Under25 = best5Overall[best5Overall['Age'] < 25].head(5)

best50Under25
# Out:
#         ID                 Name                          FullName  Age  \
# 2   231747            K. Mbappé                     Kylian Mbappé   23
# 29  239085           E. Haaland                    Erling Haaland   21
# 28  230621        G. Donnarumma              Gianluigi Donnarumma   23
# 39  231281  T. Alexander-Arnold            Trent Alexander-Arnold   23
# 57  238794         Vinícius Jr.  Vinícius José de Oliveira Júnior   21
#
#     Height  Weight Nationality  Overall  Potential  Growth BestPosition  \
# 2      182      73      France       91         95       4           ST
# 29     195      94      Norway       88         94       6           ST
# 28     196      90       Italy       88         92       4           GK
# 39     180      69     England       87         90       3           CM
# 57     176      73      Brazil       86         92       6           LW
#
#                    Club   ValueEUR  WageEUR  GMValue FirstName  \
# 2   Paris Saint-Germain  190500000   230000     85.9        K.
# 29      Manchester City  148000000   220000     85.2        E.
# 28  Paris Saint-Germain  103500000   110000     83.2        G.
# 39            Liverpool  100500000   150000     81.3        T.
# 57       Real Madrid CF  109000000   200000     83.4  Vinícius
#
#             LastName
# 2             Mbappé
# 29           Haaland
# 28        Donnarumma
# 39  Alexander-Arnold
# 57               Jr.

# %%
#Question3 Task2
tallestPlayer = df_task1.sort_values('Height', ascending=False).head(3)
tallestPlayer
# Out:
#            ID       Name     FullName  Age  Height  Weight     Nationality  \
# 15344  270513  K. Hudlin  Kyle Hudlin   22     206      85         England
# 13618  199321    T. Holý   Tomáš Holý   30     206     102  Czech Republic
# 7663   258972   I. Touré  Isaak Touré   19     204      75          France
#
#        Overall  Potential  Growth BestPosition                    Club  \
# 15344       59         67       8           ST           AFC Wimbledon
# 13618       62         62       0           GK         Carlisle United
# 7663        67         83      16           CB  Olympique de Marseille
#
#        ValueEUR  WageEUR  GMValue FirstName LastName
# 15344    500000     3000     61.1        K.   Hudlin
# 13618    275000     2000     55.8        T.     Holý
# 7663    2500000     6000     76.3        I.    Touré

# %%
#Question4 Task2
bestCanadaPlayer = best5Overall[best5Overall['Nationality'] == "Canada"].head(1)


bestCanadaPlayer
# Out:
#          ID       Name         FullName  Age  Height  Weight Nationality  \
# 130  234396  A. Davies  Alphonso Davies   21     185      77      Canada
#
#      Overall  Potential  Growth BestPosition               Club  ValueEUR  \
# 130       84         89       5           LM  FC Bayern München  60500000
#
#      WageEUR  GMValue FirstName LastName
# 130    59000     80.6        A.   Davies

# %% [markdown]
# ## Task 3 - Evaluating groups of players (30 marks)
#
# For task 3, we are interested in subgroups of players, rather than individuals.
#
# 1. What are the 5 nations with the highest average overall score and that at least 50 players are listed in the dataset?
#
#     **Answer:** *Brazil, Czech Republic, Mexico, Portugal, Algeria*
#
#
# 2. Which 5 clubs are paying the highest total wage to their players?
#
#     **Answer:** *Real Madrid CF, FC Barcelona, Manchester City, Chelsea, Liverpool*
#
#
# 3. What is the average potential and average overall score for each group age younger than 19 (including 19 years old players)? Could you find any trend? Please discuss
#
#     **Answer:** *The trend shows an increase in the average overall score as the age increases.
#     The trend shows a decrease in the average potential score as the age increases. Exclusion for 19 years old apply who have a higher potential than 18 years olds. *

# %%
import numpy as np
# Type your answers here #
# You may use multiple cells, but make sure you answer # 
# the questions using the cell above #

best5 = df_task1.groupby(["Nationality"]).agg({"Overall":["mean"]}).sort_values(by=("Overall", "mean"), ascending = False)
best5 = best5.loc[df_task1.groupby(["Nationality"])["Nationality"].count()>50].head(5)
best5
# Out:
#                   Overall
#                      mean
# Nationality
# Brazil          71.523876
# Czech Republic  71.285714
# Mexico          70.631579
# Portugal        69.804290
# Algeria         69.576271

# %%
#Question2 Task3
highestWageClub = df_task1.groupby('Club')["WageEUR"].sum().reset_index()
highestWageClub = highestWageClub.sort_values('WageEUR', ascending=False)
highestWageClub = highestWageClub.head(5)

highestWageClub
# Out:
#                 Club  WageEUR
# 495   Real Madrid CF  4718000
# 230     FC Barcelona  4107000
# 400  Manchester City  3657000
# 134          Chelsea  3330000
# 389        Liverpool  3139000

# %%
#Question2 Task4
print(f"Task 4.", "\n")
averagePotential = df_task1.groupby('Age').agg({'Potential':['mean']}).reset_index()
averageOverall =   df_task1.groupby('Age').agg({'Overall':['mean']}).reset_index()
averagePotential = averagePotential[averagePotential['Age']<=19]
averageOverall = averageOverall[averageOverall['Age']<=19]

display(averagePotential)
display(averageOverall)
print("The trend shows an increase in the average overall score as the age increases.")
# Out:
# Task 4.
#   Age  Potential
#             mean
# 0  16  74.454545
# 1  17  73.805310
# 2  18  73.262324
# 3  19  73.435923
#   Age    Overall
#             mean
# 0  16  54.727273
# 1  17  55.774336
# 2  18  57.455986
# 3  19  59.646821
# The trend shows an increase in the average overall score as the age increases.

# %% [markdown]
# ## Task 4 - Simple plots (25 marks)
#
# 1. Create a scatter plot for players from Canada with the x axis as *Overall* and the y axis as *WageEUR*. By looking at this plot, could you identify some type of relation between the overall attribute and the player's wage?
#
# **Answer:** *I can clearly identify that the higher the overall performance of a player, the more wage they are paid for the most part. Some exclusions apply. Most players are paid under 200,000*
#
#
# 2. Create a bar chart for the average wage per position (use Best Position for a players position). By looking at this plot, what is the position that you would choose to play if you are looking to have the highest probability of having a high wage?
#
# **Answer:** *I would choose to be a CF as it pays the most*
#
# 3. Plot a line chart with the x axis as age, and the y axis as the average GMValue. Include only ages 18 to 30. How would you interpret the relation between these two attributes?
#
# **Answer:** *As the age increases, the GMValue for most of the players decrease up until almost 29 years old, after which the GMValue increases for older players that is because of excellent world class players like L. Messi, C. Ronaldo etc.*

# %%
# Type your answers here #
# You may use multiple cells, but make sure you answer # 
# the questions using the cell above #
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 3, figsize=(16, 4))

#Task1
plot1 = df_task1[df_task1["Nationality"]== "Canada"]
plot_x = plot1[["Overall"]]
plot_y = plot1[["WageEUR"]]
x = plot_x
y = plot_y
axs[0].set_title('Canadian Players Scatterplot')
axs[0].scatter(x, y, color='navy')
axs[0].set(xlabel='Overall', ylabel='WageEUR')

#Task2
plot2 = df_task1.groupby("BestPosition")["WageEUR"].mean().reset_index()
y2= plot2["WageEUR"]
x2 = plot2["BestPosition"]
axs[1].set_title('Bar Chart Based On Average Wage Per Position')
axs[1].barh(x2, y2, edgecolor="white", color='red', linewidth=0.7)
axs[1].set(xlabel='WageEUR', ylabel='Position')

#Task3
plot3 = df_task1[(df_task1["Age"]>= 18) & (df_task1["Age"]<= 30)] 
#plot3 = df_task1[df_task1["Age"]<= 30]
plot3 = plot3.groupby("Age")["GMValue"].mean().reset_index()
plot_x3 = plot3[["Age"]]
plot_y3 = plot3[["GMValue"]]
x3 = plot_x3
y3 = plot_y3
axs[2].set_title("Line Chart of Player's Ages and GM Values")
axs[2].plot(x3, y3, color= 'green')
axs[2].set(xlabel='Age', ylabel='GMValue')
plt.show()

# %% [markdown]
# ## (Graduate students only) - Task 5 - Using plots to answer questions (30 marks)
#
# **Yes, the total marks for graduate students sums to 130 marks and only if you get all of those you will be scoring 100% in this assignment**
#
# For all plots below, we are only considering players from England, Germany, Spain, and Argentina (can be retrieved by column *country*).
# Make sure you include the appropriate axis labels, title, and legend if required.
#
# ### Plot 1
#
# 1. Create two box plots side by side.
#
#     a. The first should have all the player data with the x axis being the region the player is from.
#
#     b. The second should be a boxplot with the top 5% and bottom 5% of players removed from the dataset (From the 5th-95th percentile). You can use the quantile function to do this.
#
#
# 2. Which country had the best change in overall mean, and which country the worst? Why would these changes occur? (Please include a few sentences)
#
# **Answer:** *--- Please type your answer here ---*

# %%
# Type your answers here #
# You may use multiple cells, but make sure you answer # 
# the questions using the cell above #

# %% [markdown]
# ### Plot 2
#
# In this task, we are interested if certain countries are better at producing different kinds of players. For this exercise, we are not interested in the goal keeper. The X axis of your charts should be the Nationality of the player, and the bars should be split by position for each nationality. You can assume that players only play the position defined under BestPosition. You can ignore additional positions that are not defined below.
#
# 1. The first plot must be a grouped bar chart for Forwards for each Country. Positions (LW, ST, RW).
#
# **Answer:** *--- Please type your answer here ---*
#
#
# 2. The second is a grouped bar chart for Midfielders. Positions (LM, RM, CM)
#
# **Answer:** *--- Please type your answer here ---*
#
#
# 3. The third plot is a grouped bar chart for Defenders. Positions (LB, RB, CB)
#
# **Answer:** *--- Please type your answer here ---*
#
#
# 4. The fourth plot is a grouped bar chart except instead of grouping by position, we will group by forwards, midfielders, and defenders.
#
# **Answer:** *--- Please type your answer here ---*

# %%
# Type your answers here #
# You may use multiple cells, but make sure you answer # 
# the questions using the cell above #
